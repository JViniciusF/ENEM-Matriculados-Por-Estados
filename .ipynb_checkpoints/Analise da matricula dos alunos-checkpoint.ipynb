# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
low_memory = False

# %%
uri_Uni = "https://raw.githubusercontent.com/JViniciusF/Matriculados-X-Estados/master/Principais%20Informa%C3%A7%C3%B5esUni%202017.csv"
uri_Insc2017 = "https://raw.githubusercontent.com/JViniciusF/Matriculados-X-Estados/master/Principais%20Informa%C3%A7%C3%B5es%20Inscritos%202017.csv"
uri_Vagas2017 = "https://raw.githubusercontent.com/JViniciusF/Matriculados-X-Estados/master/Vagas2017.csv"
uri_Ingreso2017= "https://raw.githubusercontent.com/JViniciusF/Matriculados-X-Estados/master/Ingresos2017.csv"

# %%
df = pd.read_csv(uri_Insc2017,sep = ";")
df.columns = ["Regiao","Estados","SiglaRe","2017","2016"]
estados = df["Estados"].sort_values()
O2016 = df["2016"]
O2017 = df["2017"]
x = np.arange(len(estados))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, O2016, width, label='2016')
rects2 = ax.bar(x + width/2, O2017, width, label='2017')
ax.set_xticks(x)
ax.set_xticklabels(estados)
ax.legend()
plt.title("Numero de Inscritos ");
plt.rcParams['figure.figsize'] = (15,7)
plt.grid()
plt.autoscale()

# %%
df = pd.read_csv(uri_Ingreso2017,sep = ";")
df.columns = ["Regiao","Estados","Sigla","Sub","2017","2016"]
estados = df["Estados"]
O2016 = df["2016"]
O2017 = df["2017"]
x = np.arange(len(estados.sort_values()))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, O2016, width, label='2016')
rects2 = ax.bar(x + width/2, O2017, width, label='2017')
ax.set_xticks(x)
ax.set_xticklabels(estados)
ax.legend()
plt.title("Numero de Ingressantes nas Faculdades Publicas");
plt.rcParams['figure.figsize'] = (15,7)
plt.grid()
plt.autoscale()

# %%
df = pd.read_csv(uri_Vagas2017,sep = ";")
df.columns = ["Regiao","Estados","Cat","Sub","2017","2016"]
estados = df["Estados"]
O2016 = df["2016"]
O2017 = df["2017"]
x = np.arange(len(estados))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, O2016, width, label='2016')
rects2 = ax.bar(x + width/2, O2017, width, label='2017')
ax.set_xticks(x)
ax.set_xticklabels(estados)
ax.legend()
plt.title("Numero de Vagas em Faculdades Publicas");
plt.rcParams['figure.figsize'] = (15,7)
plt.grid()
plt.autoscale()
